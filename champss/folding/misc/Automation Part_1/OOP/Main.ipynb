# %%
#Actual running
from datetime import datetime
from Module_multiday import MultidayCandidatePipeline


db_config = {
    'host': 'sps-archiver1',
    'user': 'automation',
    'port': 3306,
    'password': '',
    'database': 'champss'
}

pipeline = MultidayCandidatePipeline(
    db_config=db_config,
    start_date=datetime(2026,1,20),
    end_date=datetime(2026,1,31),
    classifications=['<faint>', 'NEW CANDIDATE']
)

pipeline.run()
# Out:
# ===== Processing 2026-01-20 =====
# Found 1 candidates for <faint>
# Source md_303.61_56.25_9.638704_220.41 already in the follow-up source database.
# /home/rtellier/miniconda3/envs/champss2/lib/python3.11/site-packages/pydantic/main.py:250: FutureWarning: WORKFLOW_TOKEN missing. Token auth will be required in the future.
#   validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
# 16 Mar 2026 18:38:24 UTC INFO      root Initial buckets entries: []
# 16 Mar 2026 18:38:24 UTC INFO      root Final buckets entries: []
# /mnt/beegfs-client/raw/2026/01/20 42
# /mnt/beegfs-client/raw/2026/01/21 42
# Folding 2 days of data: ['20260120', '20260121']
# 16 Mar 2026 18:38:32 UTC INFO      root Creating Docker Service:
#                                   {'image': 'sps-archiver1.chime:5000/champss_software:latest', 'name':
#                                   'processing-fold-multiday-20260120-697b7857dad56d5360e236c5', 'command':
#                                   'workflow run champss-fold-multiday --tag 69b84e2816a7022f49f528ff --site chime
#                                   --lives 1 --sleep 1', 'env': ['CONTAINER_NAME={{.Task.Name}}',
#                                   'NODE_NAME={{.Node.Hostname}}'], 'mode': {'replicated': {'Replicas': 1}},
#                                   'restart_policy': {'Condition': 'none', 'Delay': 0, 'MaxAttempts': 0, 'Window':
#                                   0}, 'labels': {'type': 'processing'}, 'constraints': ['node.labels.compute ==
#                                   true'], 'resources': {'Reservations': {'MemoryBytes': 16000000000}}, 'mounts':
#                                   [{'Target': '/var/run/docker.sock', 'Source': '/var/run/docker.sock', 'Type':
#                                   'bind', 'ReadOnly': False}, {'Target': '/dev/shm', 'Source': '', 'Type': 'tmpfs',
#                                   'ReadOnly': False, 'TmpfsOptions': {'SizeBytes': 100000000000}}, {'Target':
#                                   '/mnt/beegfs-client/raw/', 'Source': '/mnt/beegfs-client/raw/', 'Type': 'bind',
#                                   'ReadOnly': False}, {'Target': '/mnt/beegfs-client/processed/archives/',
#                                   'Source': '/mnt/beegfs-client/processed/archives/', 'Type': 'bind', 'ReadOnly':
#                                   False}], 'networks': ['pipeline-network']}
# 16 Mar 2026 18:38:33 UTC INFO      root Creating Docker Service:
#                                   {'image': 'sps-archiver1.chime:5000/champss_software:latest', 'name':
#                                   'processing-fold-multiday-20260121-697b7857dad56d5360e236c5', 'command':
#                                   'workflow run champss-fold-multiday --tag 69b84e2916a7022f49f52900 --site chime
#                                   --lives 1 --sleep 1', 'env': ['CONTAINER_NAME={{.Task.Name}}',
#                                   'NODE_NAME={{.Node.Hostname}}'], 'mode': {'replicated': {'Replicas': 1}},
#                                   'restart_policy': {'Condition': 'none', 'Delay': 0, 'MaxAttempts': 0, 'Window':
#                                   0}, 'labels': {'type': 'processing'}, 'constraints': ['node.labels.compute ==
#                                   true'], 'resources': {'Reservations': {'MemoryBytes': 16000000000}}, 'mounts':
#                                   [{'Target': '/var/run/docker.sock', 'Source': '/var/run/docker.sock', 'Type':
#                                   'bind', 'ReadOnly': False}, {'Target': '/dev/shm', 'Source': '', 'Type': 'tmpfs',
#                                   'ReadOnly': False, 'TmpfsOptions': {'SizeBytes': 100000000000}}, {'Target':
#                                   '/mnt/beegfs-client/raw/', 'Source': '/mnt/beegfs-client/raw/', 'Type': 'bind',
#                                   'ReadOnly': False}, {'Target': '/mnt/beegfs-client/processed/archives/',
#                                   'Source': '/mnt/beegfs-client/processed/archives/', 'Type': 'bind', 'ReadOnly':
#                                   False}], 'networks': ['pipeline-network']}
# 16 Mar 2026 18:38:41 UTC INFO      root Removing finished service
#                                   processing-fold-multiday-20260120-697b7857dad56d5360e236c5 in state complete.
# 16 Mar 2026 18:41:27 UTC INFO      root Removing finished service
#                                   processing-fold-multiday-20260121-697b7857dad56d5360e236c5 in state complete.
# Finished multiday folding, beginning the coherent search
# 16 Mar 2026 18:41:28 UTC INFO      root Initial buckets entries: [{'id': '69b8498241797e2f3fcc510c'}]
# 16 Mar 2026 18:41:28 UTC INFO      root Will delete buckets entries with ids: ['69b8498241797e2f3fcc510c']
# 16 Mar 2026 18:41:28 UTC INFO      chimefrb.workflow.http.buckets Response from Buckets: true
# 16 Mar 2026 18:41:28 UTC INFO      root Final buckets entries: []
# 16 Mar 2026 18:41:28 UTC INFO      root Creating Docker Service:
#                                   {'image': 'sps-archiver1.chime:5000/champss_software:latest', 'name':
#                                   'processing-multiday-confirm-697b7857dad56d5360e236c5', 'command': 'workflow run
#                                   champss-multiday-confirm --tag 69b84ed816a7022f49f52901 --site chime --lives 1
#                                   --sleep 1', 'env': ['CONTAINER_NAME={{.Task.Name}}',
#                                   'NODE_NAME={{.Node.Hostname}}'], 'mode': {'replicated': {'Replicas': 1}},
#                                   'restart_policy': {'Condition': 'none', 'Delay': 0, 'MaxAttempts': 0, 'Window':
#                                   0}, 'labels': {'type': 'processing'}, 'constraints': ['node.labels.compute ==
#                                   true'], 'resources': {'Reservations': {'MemoryBytes': 64000000000}}, 'mounts':
#                                   [{'Target': '/var/run/docker.sock', 'Source': '/var/run/docker.sock', 'Type':
#                                   'bind', 'ReadOnly': False}, {'Target': '/dev/shm', 'Source': '', 'Type': 'tmpfs',
#                                   'ReadOnly': False, 'TmpfsOptions': {'SizeBytes': 100000000000}}, {'Target':
#                                   '/mnt/beegfs-client/raw/', 'Source': '/mnt/beegfs-client/raw/', 'Type': 'bind',
#                                   'ReadOnly': False}, {'Target': '/mnt/beegfs-client/processed/archives/',
#                                   'Source': '/mnt/beegfs-client/processed/archives/', 'Type': 'bind', 'ReadOnly':
#                                   False}], 'networks': ['pipeline-network']}
